# %%
import os 
os.chdir(os.path.join(os.getcwd(), '..'))

# %%
import sys; print(sys.version)
import mlflow; print(mlflow.__version__); print(mlflow.__file__)
import alembic; print(alembic.__version__); print(alembic.__file__)
# Out:
# 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
# 3.16.0
# d:\learning\learning\programing\portfolio_projects\1_image\venv\Lib\site-packages\mlflow\__init__.py
# 1.20.0
# d:\learning\learning\programing\portfolio_projects\1_image\venv\Lib\site-packages\alembic\__init__.py

# %%
os.getcwd()
# Out:
# 'd:\\learning\\learning\\programing\\portfolio_projects\\1_image'

# %%
print(sys.executable)
print(sys.path)
# Out:
# C:\Users\vital\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe
# ...
